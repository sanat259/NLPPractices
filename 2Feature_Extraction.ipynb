# %% [markdown]
# <a href="https://colab.research.google.com/github/sanat259/NLPPractices/blob/main/2Feature_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
dataset = pd.read_csv("/content/clean_data_final.csv", encoding='utf-8')

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'title', 'job_url', 'company_name', 'location',
#        'year_experience', 'salary', 'description', 'industry', 'skills',
#        'function', 'roles', 'min_qualification', 'min_salary', 'max_salary',
#        'min_experience', 'max_experience'],
#       dtype='object')

# %%
corpus =dataset.description.str.replace("[^a-zA-Z0-9 ]+", "",regex=True)

# %%
#corpus = dataset.description
print(corpus[1:3])
# Out:
# 1    Join a wellfunded firm that is revolutionising...
# 2    We have urgent requirement of Engineer Artific...
# Name: description, dtype: object

# %%
from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer 
import nltk 
# get the words for all our tasks.
nltk.download('wordnet')
nltk.download('punkt')
class LemmaTokenizer:
  def __init__(self):
    self.wnl = WordNetLemmatizer()
  def __call__(self, doc):
    return [self.wnl.lemmatize(t) for t in word_tokenize(doc)]
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
tfidf = TfidfVectorizer(min_df=0.0025, max_df=0.8, decode_error='ignore', ngram_range=(1,2), max_features=800, tokenizer=LemmaTokenizer())

# %%
features = tfidf.fit_transform(corpus)

# %%
features_df = pd.DataFrame(
    features.todense(),
    columns = tfidf.get_feature_names()
)

# %%
features_df.head()
# Out:
#      1   10   12         2  ...  you should  you will  youll      your
# 0  0.0  0.0  0.0  0.118838  ...         0.0       0.0    0.0  0.000000
# 1  0.0  0.0  0.0  0.000000  ...         0.0       0.0    0.0  0.000000
# 2  0.0  0.0  0.0  0.000000  ...         0.0       0.0    0.0  0.000000
# 3  0.0  0.0  0.0  0.000000  ...         0.0       0.0    0.0  0.059265
# 4  0.0  0.0  0.0  0.000000  ...         0.0       0.0    0.0  0.000000
#
# [5 rows x 800 columns]

# %%
tfidf.get_feature_names()
# Out:
# ['1',
#  '10',
#  '2',
#  '3',
#  '3 year',
#  '4',
#  '5',
#  '5 year',
#  '6',
#  '8',
#  'a a',
#  'a per',
#  'a similar',
#  'a team',
#  'a well',
#  'ability',
#  'ability to',
#  'able',
#  'able to',
#  'about',
#  'accurate',
#  'across',
#  'activity',
#  'advanced',
#  'after',
#  'agile',
#  'algorithm',
#  'all',
#  'along',
#  'along with',
#  'also',
#  'also be',
#  'an',
#  'analysis',
#  'analyst',
#  'analytical',
#  'analytics',
#  'analyze',
#  'and data',
#  'and develop',
#  'and ensure',
#  'and experience',
#  'and good',
#  'and implement',
#  'and other',
#  'and provide',
#  'and report',
#  'and the',
#  'and will',
#  'and written',
#  'andor',
#  'any',
#  'application',
#  'apply',
#  'architecture',
#  'are',
#  'are looking',
#  'area',
#  'at',
#  'at least',
#  'automation',
#  'available',
#  'aws',
#  'azure',
#  'bank',
#  'based',
#  'basic',
#  'be',
#  'be able',
#  'below',
#  'best',
#  'best practice',
#  'bi',
#  'big',
#  'big data',
# ...
